# %% [markdown]
# 1. feature selection
# 2. ANOVA
# 3. SMOTE
# 4. DT, LogR, XGB, SVM, RF
# 5. Ensemble technique soft voting
# 6. Data balancing (SMOTE, SMOTETomek)
# 7. Machine Learnig, Neural Network
